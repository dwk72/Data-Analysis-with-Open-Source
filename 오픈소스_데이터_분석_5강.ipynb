# %% [markdown]
# <a href="https://colab.research.google.com/github/dwk72/Data-Analysis-with-Open-Source/blob/main/%EC%98%A4%ED%94%88%EC%86%8C%EC%8A%A4_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D_5%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 오픈소스 기반 데이터 분석 5강 - 데이터 저장

# %% [markdown]
# ## 5-1 CSV 형식 저장

# %%
import pandas as pd

data = {
    'student_id': [101, 102, 103, 104, 105],
    'database_score': [85, 76, 92, 63, 88],
    'cloudcomputing_score': [78, 82, 95, 70, 84],
    'python_score': [92, 78, 85, 75, 91],
    'watch_rate': [0.95, 0.87, 0.99, 0.80, 0.93]
}
## DataFrame 생성
df = pd.DataFrame(data)
df
## CSV 형식 저장
df.to_csv('student_analysis.csv', encoding='utf-8')

# %% [markdown]
# ## 5-2 JSON 형식 저장

# %%
### 라이브러리 임포트
import json
import pandas as pd

data = {
    "이름": "홍길동",
    "나이": 25,
    "거주지": "서울",
    "관심사": ["프로그래밍", "데이터 분석", "여행"]
}

## json.dump를 이용한 저장
with open('output.json', mode='w', encoding='utf-8') as f:
    json.dump(data, f, indent=4, ensure_ascii=False)

## DataFrame을 이용한 저장
df = pd.DataFrame([data])
df.to_json('output_df.json', orient='columns', indent=4, force_ascii=False)

# %% [markdown]
# ## 5-3 Pandas Dataframe 데이터 추출

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터학", "경영학", "농학", "교육학", "영어영문학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}
df = pd.DataFrame(data)
df

## DataFrame 인덱스 출력
print(df.index)

## DataFrame 컬럼 출력
print(df.columns)

## DataFrame 행 출력
print(df.values.tolist())
print(df.values)

## DataFrame 값 출력
print(df.values.flatten())
# Out:
# RangeIndex(start=0, stop=5, step=1)
# Index(['이름', '학년', '학점', '학과', '동아리'], dtype='object')
# [['김철수', 1, 4.2, '컴퓨터학', '프로그래밍'], ['이영희', 2, 3.8, '경영학', '독서토론'], ['박민수', 3, 4.5, '농학', '로봇공학'], ['최지훈', 4, 3.9, '교육학', '봉사활동'], ['정소희', 2, 3.5, '영어영문학', '음악감상']]
# [['김철수' 1 4.2 '컴퓨터학' '프로그래밍']
#  ['이영희' 2 3.8 '경영학' '독서토론']
#  ['박민수' 3 4.5 '농학' '로봇공학']
#  ['최지훈' 4 3.9 '교육학' '봉사활동']
#  ['정소희' 2 3.5 '영어영문학' '음악감상']]
# ['김철수' 1 4.2 '컴퓨터학' '프로그래밍' '이영희' 2 3.8 '경영학' '독서토론' '박민수' 3 4.5 '농학'
#  '로봇공학' '최지훈' 4 3.9 '교육학' '봉사활동' '정소희' 2 3.5 '영어영문학' '음악감상']

# %% [markdown]
# ## 5-4 DataFrame 생성 방법

# %%
import pandas as pd
import json

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터공학", "경영학", "전자공학", "의학", "심리학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}

## 딕셔너리, csv, json으로 부터 DataFrame 생성
df1 = pd.DataFrame.from_dict(data)
df2 = pd.read_csv('students.csv')
df3 = pd.read_json('students.json')

## 세가지 방법 결과 비교
print(df1.shape)
print(df2.shape)
print(df3.shape)
# Out:
# (5, 5)
# (5, 5)
# (5, 5)

# %% [markdown]
# ## 5-5 DataFrame 저장 방법

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터공학", "경영학", "전자공학", "의학", "심리학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}

## Dataframe 생성
df = pd.DataFrame(data)

## CSV, JSON 형식으로 저장
df.to_csv('students_scores.csv')
df.to_json('students_scores.json')

## HTML 형식으로 저장
html_table = df.to_html()
with open('students_scores.html', 'w') as f:
    f.write(html_table)

# %% [markdown]
# ## 5-6 실습 시나리오

# %% [markdown]
# ## 데이터 수집

# %%
import requests

url = "http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty"
api_key = 'e4232b444db44979520cff68e3146d872b5082519c74fdc39b4782a2f1657a52'

params = {
    'serviceKey': api_key,
    'returnType': 'json',
    'numOfRows': '100',
    'pageNo': '1',
    'sidoName': '서울',
    'ver': '1.0'
}

## 데이터 수집
response = requests.get(url, params=params)

## 호출 성공/실패 출력
print(response.json())
# Out:
# {'response': {'body': {'totalCount': 40, 'items': [{'so2Grade': '1', 'coFlag': None, 'khaiValue': '56', 'so2Value': '0.002', 'coValue': '0.2', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '24', 'khaiGrade': '2', 'pm25Value': '13', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-06 17:00', 'coGrade': '1', 'no2Value': '0.008', 'stationName': '중구', 'pm10Grade': '1', 'o3Value': '0.036'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '50', 'so2Value': '0.003', 'coValue': '0.3', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '22', 'khaiGrade': '1', 'pm25Value': '11', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-06 17:00', 'coGrade': '1', 'no2Value': '0.014', 'stationName': '한강대로', 'pm10Grade': '1', 'o3Value': '0.030'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '56', 'so2Value': '0.002', 'coValue': '0.2', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '24', 'khaiGrade': '2', 'pm25Value': '13', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-06 17:00', 'coGrade': '1', 'no2Value': '0.014', 'stationName': '종로구', 'pm10Grade': '1', 'o3Value': '0.036'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '38', 'so2Value': '0.003', 'coValue': '0.3', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '27', 'khaiGrade': '1', 'pm25Value': '13', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-06 17:00', 'coGrade': '1', 'no2Value': '0.013', 'stationName': '청계천로', 'pm10Grade': '1', 'o3Value': '0.021'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '42', 'so2Value': '0.002', 'coValue': '0.3', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '26', 'khaiGrade': '1', 'pm25Value': '13', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-06 17:00', 'coGrade': '1', 'no2Value': '0.019', 'stationName': '종로', 'pm10Grade': '1', 'o3Value': '0.025'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '52', 'so2Value': '0.002', 'coValue': '0.2', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '15', 'khaiGrade': '2', 'pm25Value': '12', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-06 17:00', 'coGrade': '1', 'no2Value': '0.007', 'stationName': '용산구', 'pm10Grade': '1', 'o3Value': '0.032'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '66', 'so2Value': '0.003', 'coValue': '0.3', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '25', 'khaiGrade': '2', 'pm25Value': '12', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-06 17:00', 'coGrade': '1', 'no2Value': '0.007', 'stationName': '광진구', 'pm10Grade': '1', 'o3Value': '0.048'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '58', 'so2Value': '0.002', 'coValue': '0.2', 'pm25Flag': '통신장애', 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '22', 'khaiGrade': '2', 'pm25Value': '-', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-06 17:00', 'coGrade': '1', 'no2Value': '0.008', 'stationName': '성동구', 'pm10Grade': '1', 'o3Value': '0.038'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '-', 'so2Value': '0.003', 'coValue': '0.2', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '23', 'khaiGrade': None, 'pm25Value': '5', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-06 17:00', 'coGrade': '1', 'no2Value': '0.014', 'stationName': '강변북로', 'pm10Grade': None, 'o3Value': '0.032'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '-' ...

# %%
response.json()
# Out:
# {'response': {'body': {'totalCount': 40,
#    'items': [{'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '56',
#      'so2Value': '0.002',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '24',
#      'khaiGrade': '2',
#      'pm25Value': '13',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.008',
#      'stationName': '중구',
#      'pm10Grade': '1',
#      'o3Value': '0.036'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '50',
#      'so2Value': '0.003',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '22',
#      'khaiGrade': '1',
#      'pm25Value': '11',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.014',
#      'stationName': '한강대로',
#      'pm10Grade': '1',
#      'o3Value': '0.030'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '56',
#      'so2Value': '0.002',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '24',
#      'khaiGrade': '2',
#      'pm25Value': '13',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.014',
#      'stationName': '종로구',
#      'pm10Grade': '1',
#      'o3Value': '0.036'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '38',
#      'so2Value': '0.003',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '27',
#      'khaiGrade': '1',
#      'pm25Value': '13',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.013',
#      'stationName': '청계천로',
#      'pm10Grade': '1',
#      'o3Value': '0.021'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '42',
#      'so2Value': '0.002',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '26',
#      'khaiGrade': '1',
#      'pm25Value': '13',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.019',
#      'stationName': '종로',
#      'pm10Grade': '1',
#      'o3Value': '0.025'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '52',
#      'so2Value': '0.002',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '15',
#      'khaiGrade': '2',
#      'pm25Value': '12',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.007',
#      'stationName': '용산구',
#      'pm10Grade': '1',
#      'o3Value': '0.032'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '66',
#      'so2Value': '0.003',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '25',
#      'khaiGrade': '2',
#      'pm25Value': '12',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.007',
#      'stationName': '광진구',
#      'pm10Grade': '1',
#      'o3Value': '0.048'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '58',
#      'so2Value': '0.002',
#      'coValue': '0.2',
#      'pm25Flag': '통신장애',
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '22',
#      'khaiGrade': '2',
#      'pm25Value': '-',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.008',
#      'stationName': '성동구',
#      'pm10Grade': '1',
#      'o3Value': '0.038'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '-',
#      'so2Value': '0.003',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '23',
#      'khaiGrade': None,
#      'pm25Value': '5',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.014',
#      'stationName': '강변북로',
#      'pm10Grade': None,
#      'o3Value': '0.032'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '-',
#      'so2Value': '0.002',
#      'coValue': '0.2',
#      'pm25Flag': '통신장애',
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '27',
#      'khaiGrade': None,
#      'pm25Value': '-',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': None,
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.007',
#      'stationName': '중랑구',
#      'pm10Grade': '1',
#      'o3Value': '0.040'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '54',
#      'so2Value': '0.003',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '32',
#      'khaiGrade': '2',
#      'pm25Value': '14',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.011',
#      'stationName': '동대문구',
#      'pm10Grade': '1',
#      'o3Value': '0.034'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '46',
#      'so2Value': '0.002',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '32',
#      'khaiGrade': '1',
#      'pm25Value': '14',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.015',
#      'stationName': '홍릉로',
#      'pm10Grade': '1',
#      'o3Value': '0.028'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '58',
#      'so2Value': '0.003',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '15',
#      'khaiGrade': '2',
#      'pm25Value': '8',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.005',
#      'stationName': '성북구',
#      'pm10Grade': '1',
#      'o3Value': '0.038'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '51',
#      'so2Value': '0.002',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '25',
#      'khaiGrade': '2',
#      'pm25Value': '9',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.017',
#      'stationName': '정릉로',
#      'pm10Grade': '1',
#      'o3Value': '0.031'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '61',
#      'so2Value': '0.003',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '23',
#      'khaiGrade': '2',
#      'pm25Value': '8',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.004',
#      'stationName': '도봉구',
#      'pm10Grade': '1',
#      'o3Value': '0.043'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '56',
#      'so2Value': '0.003',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '15',
#      'khaiGrade': '2',
#      'pm25Value': '6',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.006',
#      'stationName': '은평구',
#      'pm10Grade': '1',
#      'o3Value': '0.037'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '64',
#      'so2Value': '0.003',
#      'coValue': '0.4',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '15',
#      'khaiGrade': '2',
#      'pm25Value': '7',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.004',
#      'stationName': '서대문구',
#      'pm10Grade': '1',
#      'o3Value': '0.046'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '55',
#      'so2Value': '0.002',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '15',
#      'khaiGrade': '2',
#      'pm25Value': '11',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.008',
#      'stationName': '마포구',
#      'pm10Grade': '1',
#      'o3Value': '0.035'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '42',
#      'so2Value': '0.003',
#      'coValue': '0.5',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '33',
#      'khaiGrade': '1',
#      'pm25Value': '13',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.025',
#      'stationName': '신촌로',
#      'pm10Grade': '1',
#      'o3Value': '0.017'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '53',
#      'so2Value': '0.002',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '25',
#      'khaiGrade': '2',
#      'pm25Value': '14',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.007',
#      'stationName': '강서구',
#      'pm10Grade': '1',
#      'o3Value': '0.032'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '54',
#      'so2Value': '0.002',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '23',
#      'khaiGrade': '2',
#      'pm25Value': '14',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.014',
#      'stationName': '공항대로',
#      'pm10Grade': '1',
#      'o3Value': '0.034'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '59',
#      'so2Value': '0.003',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '17',
#      'khaiGrade': '2',
#      'pm25Value': '6',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.005',
#      'stationName': '구로구',
#      'pm10Grade': '1',
#      'o3Value': '0.040'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '47',
#      'so2Value': '0.002',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '25',
#      'khaiGrade': '1',
#      'pm25Value': '10',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.007',
#      'stationName': '영등포구',
#      'pm10Grade': '1',
#      'o3Value': '0.028'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '37',
#      'so2Value': '0.002',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '26',
#      'khaiGrade': '1',
#      'pm25Value': '10',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.022',
#      'stationName': '영등포로',
#      'pm10Grade': '1',
#      'o3Value': '0.022'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '59',
#      'so2Value': '0.002',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '20',
#      'khaiGrade': '2',
#      'pm25Value': '11',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.007',
#      'stationName': '동작구',
#      'pm10Grade': '1',
#      'o3Value': '0.040'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '54',
#      'so2Value': '0.002',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '26',
#      'khaiGrade': '2',
#      'pm25Value': '3',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.017',
#      'stationName': '동작대로 중앙차로',
#      'pm10Grade': '1',
#      'o3Value': '0.034'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '60',
#      'so2Value': '0.002',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '23',
#      'khaiGrade': '2',
#      'pm25Value': '12',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.008',
#      'stationName': '관악구',
#      'pm10Grade': '1',
#      'o3Value': '0.041'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '58',
#      'so2Value': '0.002',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '25',
#      'khaiGrade': '2',
#      'pm25Value': '15',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.007',
#      'stationName': '강남구',
#      'pm10Grade': '1',
#      'o3Value': '0.039'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '62',
#      'so2Value': '0.003',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '14',
#      'khaiGrade': '2',
#      'pm25Value': '9',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.006',
#      'stationName': '서초구',
#      'pm10Grade': '1',
#      'o3Value': '0.043'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '60',
#      'so2Value': '0.003',
#      'coValue': '0.4',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '22',
#      'khaiGrade': '2',
#      'pm25Value': '4',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.009',
#      'stationName': '도산대로',
#      'pm10Grade': '1',
#      'o3Value': '0.042'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '54',
#      'so2Value': '0.003',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '12',
#      'khaiGrade': '2',
#      'pm25Value': '3',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.012',
#      'stationName': '강남대로',
#      'pm10Grade': '1',
#      'o3Value': '0.034'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '57',
#      'so2Value': '0.002',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '19',
#      'khaiGrade': '2',
#      'pm25Value': '9',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.006',
#      'stationName': '송파구',
#      'pm10Grade': '1',
#      'o3Value': '0.038'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '63',
#      'so2Value': '0.003',
#      'coValue': '0.5',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '20',
#      'khaiGrade': '2',
#      'pm25Value': '9',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.005',
#      'stationName': '강동구',
#      'pm10Grade': '1',
#      'o3Value': '0.045'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '57',
#      'so2Value': '0.002',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '14',
#      'khaiGrade': '2',
#      'pm25Value': '3',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.012',
#      'stationName': '천호대로',
#      'pm10Grade': '1',
#      'o3Value': '0.038'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '59',
#      'so2Value': '0.003',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '13',
#      'khaiGrade': '2',
#      'pm25Value': '8',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.010',
#      'stationName': '금천구',
#      'pm10Grade': '1',
#      'o3Value': '0.039'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '51',
#      'so2Value': '0.003',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '22',
#      'khaiGrade': '2',
#      'pm25Value': '6',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.008',
#      'stationName': '시흥대로',
#      'pm10Grade': '1',
#      'o3Value': '0.031'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '-',
#      'so2Value': '0.002',
#      'coValue': '0.2',
#      'pm25Flag': '통신장애',
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '26',
#      'khaiGrade': None,
#      'pm25Value': '-',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': None,
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.006',
#      'stationName': '강북구',
#      'pm10Grade': '1',
#      'o3Value': '0.040'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '55',
#      'so2Value': '0.002',
#      'coValue': '0.2',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '31',
#      'khaiGrade': '2',
#      'pm25Value': '12',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.007',
#      'stationName': '양천구',
#      'pm10Grade': '1',
#      'o3Value': '0.035'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '58',
#      'so2Value': '0.002',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '23',
#      'khaiGrade': '2',
#      'pm25Value': '14',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.008',
#      'stationName': '노원구',
#      'pm10Grade': '1',
#      'o3Value': '0.039'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '52',
#      'so2Value': '0.002',
#      'coValue': '0.3',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '2',
#      'pm10Value': '34',
#      'khaiGrade': '2',
#      'pm25Value': '9',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '1',
#      'so2Flag': None,
#      'dataTime': '2025-09-06 17:00',
#      'coGrade': '1',
#      'no2Value': '0.018',
#      'stationName': '화랑로',
#      'pm10Grade': '1',
#      'o3Value': '0.032'}],
#    'pageNo': 1,
#    'numOfRows': 100},
#   'header': {'resultMsg': 'NORMAL_CODE', 'resultCode': '00'}}}

# %% [markdown]
# ## 데이터 프레임 생성

# %%
import pandas as pd

## requests로부터 response, body, item 항목 읽기
data = response.json()['response']['body']['items']
print(type(data))
print(len(data))
print(data[0])
df = pd.DataFrame(data)
df
# Out:
# <class 'list'>
# 40
# {'so2Grade': '1', 'coFlag': None, 'khaiValue': '56', 'so2Value': '0.002', 'coValue': '0.2', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '24', 'khaiGrade': '2', 'pm25Value': '13', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-06 17:00', 'coGrade': '1', 'no2Value': '0.008', 'stationName': '중구', 'pm10Grade': '1', 'o3Value': '0.036'}
#    so2Grade coFlag khaiValue so2Value coValue pm25Flag pm10Flag o3Grade  \
# 0         1   None        56    0.002     0.2     None     None       2
# 1         1   None        50    0.003     0.3     None     None       1
# 2         1   None        56    0.002     0.2     None     None       2
# 3         1   None        38    0.003     0.3     None     None       1
# 4         1   None        42    0.002     0.3     None     None       1
# 5         1   None        52    0.002     0.2     None     None       2
# 6         1   None        66    0.003     0.3     None     None       2
# 7         1   None        58    0.002     0.2     통신장애     None       2
# 8         1   None         -    0.003     0.2     None     None       2
# 9         1   None         -    0.002     0.2     통신장애     None       2
# 10        1   None        54    0.003     0.2     None     None       2
# 11        1   None        46    0.002     0.3     None     None       1
# 12        1   None        58    0.003     0.3     None     None       2
# 13        1   None        51    0.002     0.3     None     None       2
# 14        1   None        61    0.003     0.2     None     None       2
# 15        1   None        56    0.003     0.3     None     None       2
# 16        1   None        64    0.003     0.4     None     None       2
# 17        1   None        55    0.002     0.2     None     None       2
# 18        1   None        42    0.003     0.5     None     None       1
# 19        1   None        53    0.002     0.3     None     None       2
# 20        1   None        54    0.002     0.3     None     None       2
# 21        1   None        59    0.003     0.2     None     None       2
# 22        1   None        47    0.002     0.2     None     None       1
# 23        1   None        37    0.002     0.3     None     None       1
# 24        1   None        59    0.002     0.2     None     None       2
# 25        1   None        54    0.002     0.3     None     None       2
# 26        1   None        60    0.002     0.2     None     None       2
# 27        1   None        58    0.002     0.2     None     None       2
# 28        1   None        62    0.003     0.3     None     None       2
# 29        1   None        60    0.003     0.4     None     None       2
# 30        1   None        54    0.003     0.3     None     None       2
# 31        1   None        57    0.002     0.2     None     None       2
# 32        1   None        63    0.003     0.5     None     None       2
# 33        1   None        57    0.002     0.3     None     None       2
# 34        1   None        59    0.003     0.3     None     None       2
# 35        1   None        51    0.003     0.2     None     None       2
# 36        1   None         -    0.002     0.2     통신장애     None       2
# 37        1   None        55    0.002     0.2     None     None       2
# 38        1   None        58    0.002     0.3     None     None       2
# 39        1   None        52    0.002     0.3     None     None       2
#
#    pm10Value khaiGrade  ... no2Grade o3Flag pm25Grade so2Flag  \
# 0         24         2  ...        1   None         1    None
# 1         22         1  ...        1   None         1    None
# 2         24         2  ...        1   None         1    None
# 3         27         1  ...        1   None         1    None
# 4         26         1  ...        1   None         1    None
# 5         15         2  ...        1   None         1    None
# 6         25         2  ...        1   None         1    None
# 7         22         2  ...        1   None         1    None
# 8         23      None  ...        1   None         1    None
# 9         27      None  ...        1   None      None    None
# 10        32         2  ...        1   None         1    None
# 11        32         1  ...        1   None         1    None
# 12        15         2  ...        1   None         1    None
# 13        25         2  ...        1   None         1    None
# 14        23         2  ...        1   None         1    None
# 15        15         2  ...        1   None         1    None
# 16        15         2  ...        1   None         1    None
# 17        15         2  ...        1   None         1    None
# 18        33         1  ...        1   None         1    None
# 19        25         2  ...        1   None         1    None
# 20        23         2  ...        1   None         1    None
# 21        17         2  ...        1   None         1    None
# 22        25         1  ...        1   None         1    None
# 23        26         1  ...        1   None         1    None
# 24        20         2  ...        1   None         1    None
# 25        26         2  ...        1   None         1    None
